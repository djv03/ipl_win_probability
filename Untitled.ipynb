# %%
import numpy as np
import pandas as pd

# %%
matches=pd.read_csv('matches.csv')
deliveries=pd.read_csv('deliveries.csv')

# %%
# getting runs of each inning from deliveries.csv, 

total_score_df= deliveries.groupby(['match_id','inning']).sum()['total_runs'].reset_index()
total_score_df

# storing this result in the variable for further use
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 1            1       2         172
# 2            2       1         184
# 3            2       2         187
# 4            3       1         183
# ...        ...     ...         ...
# 1523     11413       2         170
# 1524     11414       1         155
# 1525     11414       2         162
# 1526     11415       1         152
# 1527     11415       2         157
#
# [1528 rows x 3 columns]

# %%
# getting score of first inning of each match
total_score_df= total_score_df[total_score_df['inning']==1]
total_score_df
# Out:
#       match_id  inning  total_runs
# 0            1       1         207
# 2            2       1         184
# 4            3       1         183
# 6            4       1         163
# 8            5       1         157
# ...        ...     ...         ...
# 1518     11347       1         143
# 1520     11412       1         136
# 1522     11413       1         171
# 1524     11414       1         155
# 1526     11415       1         152
#
# [756 rows x 3 columns]

# %%
# merging this data into our first table(matches), 
match_df= matches.merge(total_score_df[['match_id','total_runs']], left_on='id',right_on='match_id')
match_df
# Out:
#         id    Season           city        date                        team1  \
# 0        1  IPL-2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune  06-04-2017               Mumbai Indians
# 2        3  IPL-2017         Rajkot  07-04-2017                Gujarat Lions
# 3        4  IPL-2017         Indore  08-04-2017       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..     ...       ...            ...         ...                          ...
# 751  11347  IPL-2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai  07-05-2019          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12-05-2019               Mumbai Indians
#
# ...

# %%
# some data cleaning tasks
# 1. replacing teams names, if changes ex: delhi daredevils replace by delhi capitals 

match_df['team1']=match_df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
match_df['team2']=match_df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

match_df['team1']=match_df['team1'].str.replace('Kings XI Punjab','Punjab Kings')
match_df['team2']=match_df['team2'].str.replace('Kings XI Punjab','Punjab Kings')



match_df['team1']=match_df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
match_df['team2']=match_df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
# 2. removing teams which are not longer playing


# match_df['team1'].unique() //getting all unique values in columns
teams=['Sunrisers Hyderabad', 
       'Mumbai Indians',
       'Royal Challengers Bangalore',
       'Kolkata Knight Riders',
       'Delhi Capitals', 
       'Punjab Kings',
       'Chennai Super Kings',
       'Rajasthan Royals'
      ]
match_df= match_df[match_df['team1'].isin(teams)]
match_df= match_df[match_df['team2'].isin(teams)]

# %%
match_df= match_df[match_df['dl_applied']==0]
match_df.shape

# now our data is cleaned with 626 rows remained
# Out:
# (626, 20)

# %% [markdown]
# ## now merging necessary data from two tables
# now we want to achive ball by ball data along with which city that ball is bowled and who was winner their while chasing respective target

# %%
# extracting relevant infor from our manipulated matches.csv
match_df=match_df[['match_id','city','winner','total_runs','date']]

# %%
delivery_df=match_df.merge(deliveries,on='match_id')

# %%
delivery_df=delivery_df[delivery_df['inning']==2]

# %%
delivery_df
# Out:
#         match_id       city               winner  total_runs_x        date  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207  05-04-2017
# 126            1  Hyderabad  Sunrisers Hyderabad           207  05-04-2017
# 127            1  Hyderabad  Sunrisers Hyderabad           207  05-04-2017
# 128            1  Hyderabad  Sunrisers Hyderabad           207  05-04-2017
# 129            1  Hyderabad  Sunrisers Hyderabad           207  05-04-2017
# ...          ...        ...                  ...           ...         ...
# 149573     11415  Hyderabad       Mumbai Indians           152  12-05-2019
# 149574     11415  Hyderabad       Mumbai Indians           152  12-05-2019
# 149575     11415  Hyderabad       Mumbai Indians           152  12-05-2019
# 149576     11415  Hyderabad       Mumbai Indians           152  12-05-2019
# 149577     11415  Hyderabad       Mumbai Indians           152  12-05-2019
#
# ...

# %%
delivery_df['current_score']= delivery_df.groupby('match_id')['total_runs_y'].cumsum()

# %%
delivery_df['runs_left']=delivery_df['total_runs_x']-delivery_df['current_score']

# %%
delivery_df['balls_left']=126-(delivery_df['over']*6 + delivery_df['ball'])

# %%
# calculatig wickets left column

delivery_df['player_dismissed']=delivery_df['player_dismissed'].fillna("0")
delivery_df['player_dismissed']=delivery_df['player_dismissed'].apply(lambda x: x if x=="0" else "1")

delivery_df['player_dismissed'] = delivery_df['player_dismissed'].astype('int')
wickets= delivery_df.groupby('match_id')['player_dismissed'].cumsum()

delivery_df['wickets_left']= 10-wickets

# %%
# crr= runs/overs
delivery_df['crr']=(delivery_df['current_score']*6)/(120-delivery_df['balls_left'])

# %%
# rrr = runs left/overs left

delivery_df['rrr']=(delivery_df['runs_left']*6)/(delivery_df['balls_left'])

# %%
delivery_df.columns
# Out:
# Index(['match_id', 'city', 'winner', 'total_runs_x', 'date', 'inning',
#        'batting_team', 'bowling_team', 'over', 'ball', 'batsman',
#        'non_striker', 'bowler', 'is_super_over', 'wide_runs', 'bye_runs',
#        'legbye_runs', 'noball_runs', 'penalty_runs', 'batsman_runs',
#        'extra_runs', 'total_runs_y', 'player_dismissed', 'dismissal_kind',
#        'fielder', 'current_score', 'runs_left', 'balls_left', 'wickets_left',
#        'crr', 'rrr'],
#       dtype='object')

# %%
def result(row):
    return 1 if row['batting_team']==row['winner'] else 0

# %%
delivery_df['result']=delivery_df.apply(result,axis=1)
delivery_df
# Out:
#         match_id       city               winner  total_runs_x        date  \
# 125            1  Hyderabad  Sunrisers Hyderabad           207  05-04-2017
# 126            1  Hyderabad  Sunrisers Hyderabad           207  05-04-2017
# 127            1  Hyderabad  Sunrisers Hyderabad           207  05-04-2017
# 128            1  Hyderabad  Sunrisers Hyderabad           207  05-04-2017
# 129            1  Hyderabad  Sunrisers Hyderabad           207  05-04-2017
# ...          ...        ...                  ...           ...         ...
# 149573     11415  Hyderabad       Mumbai Indians           152  12-05-2019
# 149574     11415  Hyderabad       Mumbai Indians           152  12-05-2019
# 149575     11415  Hyderabad       Mumbai Indians           152  12-05-2019
# 149576     11415  Hyderabad       Mumbai Indians           152  12-05-2019
# 149577     11415  Hyderabad       Mumbai Indians           152  12-05-2019
#
# ...

# %%
final_df=delivery_df[[ 
             'batting_team',
             'bowling_team', 
             'city',
             'runs_left',
             'balls_left',
             'wickets_left', 
             'total_runs_x',
             'crr', 
             'rrr',
             'result']]

# %%
 # dropping raws which do not have city attibute

final_df.isnull().sum()
# final_df.dropna(inplace=True)
# final_df
# Out:
# batting_team      0
# bowling_team      0
# city            832
# runs_left         0
# balls_left        0
# wickets_left      0
# total_runs_x      0
# crr               0
# rrr               7
# result            0
# dtype: int64

# %%
final_df=final_df.sample(final_df.shape[0])
final_df
# Out:
#                        batting_team                 bowling_team       city  \
# 46054         Kolkata Knight Riders             Rajasthan Royals    Kolkata
# 67094   Royal Challengers Bangalore              Deccan Chargers  Bangalore
# 124109          Chennai Super Kings              Kings XI Punjab     Mohali
# 5520          Kolkata Knight Riders  Royal Challengers Bangalore  Bangalore
# 473                Delhi Daredevils  Royal Challengers Bangalore  Bangalore
# ...                             ...                          ...        ...
# 139334        Kolkata Knight Riders  Royal Challengers Bangalore  Bengaluru
# 20149              Rajasthan Royals          Chennai Super Kings     Mumbai
# 67917   Royal Challengers Bangalore               Mumbai Indians     Mumbai
# 104582             Rajasthan Royals          Chennai Super Kings  Ahmedabad
# 148311              Kings XI Punjab          Chennai Super Kings     Mohali
#
# ...

# %%
# handling cases where rrr = infinite
# occures +infinte when target is chased before 20 overs and 
#         -infinite when no balls is left to chase target 
final_df =final_df[ final_df['balls_left']!=0]

# %%
final_df.sample()
# Out:
#                  batting_team         bowling_team     city  runs_left  \
# 134930  Kolkata Knight Riders  Sunrisers Hyderabad  Kolkata        106
#
#         balls_left  wickets_left  total_runs_x        crr      rrr  result
# 134930          77             9           179  10.186047  8.25974       0

# %% [markdown]
# # Data is ready to train!
# ### we start by splitting data and then apply linearrgression(as of now) to train data

# %%
X=final_df.iloc[:,:-1] # This selects all rows and all columns except the last one for features.
y=final_df.iloc[:,-1]  # This selects all rows and only the last column for the target.

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
X_train
# Out:
#                        batting_team           bowling_team        city  \
# 43697   Royal Challengers Bangalore  Kolkata Knight Riders   Bangalore
# 39290               Deccan Chargers         Mumbai Indians      Mumbai
# 52342   Royal Challengers Bangalore       Delhi Daredevils       Delhi
# 145621             Rajasthan Royals  Kolkata Knight Riders     Kolkata
# 144146               Delhi Capitals        Kings XI Punjab       Delhi
# ...                             ...                    ...         ...
# 23543              Rajasthan Royals       Delhi Daredevils   Centurion
# 93653              Rajasthan Royals    Sunrisers Hyderabad   Ahmedabad
# 82544              Rajasthan Royals        Kings XI Punjab  Chandigarh
# 37145           Chennai Super Kings        Kings XI Punjab     Chennai
# 117088               Mumbai Indians  Kolkata Knight Riders      Mumbai
#
#         runs_left  balls_left  wickets_left  total_runs_x        crr  \
# ...

# %%
X_test
# Out:
#                        batting_team                 bowling_team  \
# 148280              Kings XI Punjab          Chennai Super Kings
# 75869   Royal Challengers Bangalore             Delhi Daredevils
# 53738               Deccan Chargers        Kolkata Knight Riders
# 47977         Kolkata Knight Riders          Chennai Super Kings
# 101931  Royal Challengers Bangalore        Kolkata Knight Riders
# ...                             ...                          ...
# 25219              Rajasthan Royals              Deccan Chargers
# 141045               Mumbai Indians              Kings XI Punjab
# 108914             Delhi Daredevils             Rajasthan Royals
# 442                Delhi Daredevils  Royal Challengers Bangalore
# 144397          Sunrisers Hyderabad        Kolkata Knight Riders
#
#                   city  runs_left  balls_left  wickets_left  total_runs_x  \
# 148280          Mohali        126          99            10           172
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf=  ColumnTransformer([
    ('trf', OneHotEncoder(sparse_output=False,drop='first'),['batting_team','bowling_team'	,'city'])
],
                        remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# %%
pipe=Pipeline(steps=[
    ('step1',trf),
    ('step2',LogisticRegression(solver='liblinear'))
])
 # ('step2',RandomForestClassifier())

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred=pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.8031866989954971

# %%
pipe.predict_proba(X_test)[110]
# Out:
# array([0.8284783, 0.1715217])

# %%
def match_progression(x_df,match_id,pipe):
    match = x_df[x_df['match_id'] == match_id]
    match = match[(match['ball'] == 6)]
    temp_df = match[['batting_team','bowling_team','city','runs_left','balls_left','wickets_left','total_runs_x','crr','rrr']].dropna()
    temp_df = temp_df[temp_df['balls_left'] != 0]
    result = pipe.predict_proba(temp_df)
    temp_df['lose'] = np.round(result.T[0]*100,1)
    temp_df['win'] = np.round(result.T[1]*100,1)
    temp_df['end_of_over'] = range(1,temp_df.shape[0]+1)
    
    target = temp_df['total_runs_x'].values[0]
    runs = list(temp_df['runs_left'].values)
    new_runs = runs[:]
    runs.insert(0,target)
    temp_df['runs_after_over'] = np.array(runs)[:-1] - np.array(new_runs)
    wickets = list(temp_df['wickets_left'].values)
    new_wickets = wickets[:]
    new_wickets.insert(0,10)
    wickets.append(0)
    w = np.array(wickets)
    nw = np.array(new_wickets)
    temp_df['wickets_in_over'] = (nw - w)[0:temp_df.shape[0]]
    
    print("Target-",target)
    temp_df = temp_df[['end_of_over','runs_after_over','wickets_in_over','lose','win']]
    return temp_df,target

# %%
temp_df,target = match_progression(delivery_df,74,pipe)
temp_df
# Out:
# Target- 178
#        end_of_over  runs_after_over  wickets_in_over  lose   win
# 10459            1                4                0  57.2  42.8
# 10467            2                8                0  51.6  48.4
# 10473            3                1                0  58.8  41.2
# 10479            4                7                1  70.0  30.0
# 10485            5               12                0  59.8  40.2
# 10491            6               13                0  47.4  52.6
# 10497            7                9                0  41.6  58.4
# 10505            8               15                0  27.7  72.3
# 10511            9                7                0  25.6  74.4
# 10518           10               17                0  14.0  86.0
# 10524           11                9                1  19.4  80.6
# 10530           12                9                0  16.0  84.0
# 10536           13                8                0  13.8  86.2
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(18,8))
plt.plot(temp_df['end_of_over'],temp_df['wickets_in_over'],color='yellow',linewidth=3)
plt.plot(temp_df['end_of_over'],temp_df['win'],color='#00a65a',linewidth=4)
plt.plot(temp_df['end_of_over'],temp_df['lose'],color='red',linewidth=4)
plt.bar(temp_df['end_of_over'],temp_df['runs_after_over'])
plt.title('Target-' + str(target))
# Out:
# Text(0.5, 1.0, 'Target-178')

# %%
teams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Delhi Capitals',
#  'Punjab Kings',
#  'Chennai Super Kings',
#  'Rajasthan Royals']

# %%
delivery_df['city'].unique()
# Out:
# array(['Hyderabad', 'Bangalore', 'Mumbai', 'Indore', 'Kolkata', 'Delhi',
#        'Chandigarh', 'Jaipur', 'Chennai', 'Cape Town', 'Port Elizabeth',
#        'Durban', 'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi', 'Abu Dhabi',
#        'Sharjah', nan, 'Mohali', 'Bengaluru'], dtype=object)

# %%
import pickle
pickle.dump(pipe,open('pipe.pkl','wb'))
